# %% [markdown]
# ### Connect to drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Colab Notebooks/ALD
# Out:
# /content/drive/MyDrive/Colab Notebooks/ALD

# %%
# %ls
# Out:
# datasets/

# %%
import os
import zipfile
import time
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import fftpack, signal
from scipy.fftpack import dct
from scipy.stats import skew, kurtosis
from datetime import datetime, timedelta

# %% [markdown]
# # **Data Extraction**
#
# ### **Accelerometer Data**
# Accelerometer data was collected from smartphones at a sampling rate of 40Hz. => T = (1/40)s = 25ms.

# %%
DATASET_PATH = 'datasets/Accelerometer Data + TAC'
ACCELEROMETER_DATA = 'all_accelerometer_data_pids_13.csv'

# %%
all_accelerometer_df = pd.read_csv(f'{DATASET_PATH}/{ACCELEROMETER_DATA}')
all_accelerometer_df.rename(columns={'time': 'timestamp'}, inplace=True)
all_accelerometer_df.head()
# Out:
#        timestamp     pid       x       y       z
# 0              0  JB3156  0.0000  0.0000  0.0000
# 1              0  CC6740  0.0000  0.0000  0.0000
# 2  1493733882409  SA0297  0.0758  0.0273 -0.0102
# 3  1493733882455  SA0297 -0.0359  0.0794  0.0037
# 4  1493733882500  SA0297 -0.2427 -0.0861 -0.0163

# %% [markdown]
# It can be seen that there're few rows with timestamp = 0 and they need to be removed.

# %%
print(f'Shape of all_accelerometer_df: {all_accelerometer_df.shape}')
# Drop null values
all_accelerometer_df.dropna(inplace=True)
# Drop rows with timestamp = 0
all_accelerometer_df = all_accelerometer_df[all_accelerometer_df['timestamp'] != 0]
print(f'Shape of all_accelerometer_df after cleaning: {all_accelerometer_df.shape}')
# Out:
# Shape of all_accelerometer_df: (14057567, 5)
# Shape of all_accelerometer_df after cleaning: (14057565, 5)

# %% [markdown]
# Grouping the dataframe by both pid and timestamp to get the accelerometer data for each participant.

# %%
all_accelerometer_df.groupby(['pid', 'timestamp']).first()
# Out:
#                            x       y       z
# pid    timestamp
# BK7610 1493735870653  0.1261 -0.0078 -0.0243
#        1493735870679  0.1336 -0.0697 -0.0446
#        1493735870703  0.1443 -0.0474 -0.0447
#        1493735870729  0.1255 -0.0038  0.0111
#        1493735870753  0.1076  0.0032  0.0276
# ...                      ...     ...     ...
# SF3079 1493790825484  0.0169  0.0426  0.2114
#        1493790825487 -0.4330  0.1745 -0.1570
#        1493790825489  0.1015  0.0213 -0.1760
#        1493790825492  0.2091 -0.0084  0.0871
#        1493790825495 -0.0067  0.0099  0.0959
#
# [14056688 rows x 3 columns]

# %% [markdown]
# The timestamp is 13 digits long. Hence, they're Unix style timestamps. => time is in milliseconds.

# %%
# Group by pid to separate out data related to each participant
accelerometer_gb = all_accelerometer_df.groupby('pid')
# For each group, get the particular dataframe and reset the index
accelerometer_data = {pid: df.sort_values(by='timestamp', ignore_index=True).drop('pid', axis=1).reset_index(drop=True) for pid, df in accelerometer_gb}
pids = list(accelerometer_data.keys())
accelerometer_data[pids[0]].head()
# Out:
#        timestamp       x       y       z
# 0  1493735870653  0.1261 -0.0078 -0.0243
# 1  1493735870679  0.1336 -0.0697 -0.0446
# 2  1493735870703  0.1443 -0.0474 -0.0447
# 3  1493735870729  0.1255 -0.0038  0.0111
# 4  1493735870753  0.1076  0.0032  0.0276

# %% [markdown]
# Checking the frequency of the timestamps.

# %%
acc_time = accelerometer_data[pids[0]]['timestamp']
acc_time = acc_time - acc_time.min()
acc_time.head(10)
# Out:
# 0      0
# 1     26
# 2     50
# 3     76
# 4    100
# 5    131
# 6    150
# 7    177
# 8    200
# 9    226
# Name: timestamp, dtype: int64

# %% [markdown]
# # Data Analysis
# Next, let's examine the lengths of the time-series data streams collected from various participants.

# %%
lengths = [(df['timestamp'].max() - df['timestamp'].min()) / (1000 * 60 * 60) for df in accelerometer_data.values()]
plt.figure(figsize=(20, 10))
plt.bar(pids, lengths)
plt.grid()
plt.xlabel('Participant ID')
plt.ylabel('Length of data stream (hours)')
plt.title('Length of data stream for each participant')
# Out:
# Text(0.5, 1.0, 'Length of data stream for each participant')

# %% [markdown]
# ## Cleaned TAC Data
# TAC data was collected using SCRAM ankle bracelets and was collected at 30 minute intervals. The cleaned TAC readings:
#
# Were processed with a zero-phase low-pass filter to smooth noise without shifting phase.
# Were shifted backwards by 45 minutes so the labels more closely match the true intoxication of the participant (since alcohol takes about 45 minutes to exit through the skin).

# %%
tac_readings = {}

for tac_file in os.listdir(f'{DATASET_PATH}/clean_tac'):
    tac_df = pd.read_csv(f'{DATASET_PATH}/clean_tac/{tac_file}')
    tac_df.sort_values(by='timestamp', inplace=True, ignore_index=True)
    # Drop null values
    tac_df.dropna(inplace=True)
    # Drop rows with timestamp = 0
    tac_df = tac_df[tac_df['timestamp'] != 0]
    tac_readings[tac_file.split('_')[0]] = tac_df

tac_readings[pids[0]].head()
# Out:
#     timestamp  TAC_Reading
# 0  1493718714    -0.000482
# 1  1493720697     0.001573
# 2  1493721027     0.002144
# 3  1493721357     0.000877
# 4  1493721686    -0.001145

# %% [markdown]
# The timestamp is 10 digits long. => time is in seconds. Let's check the frequency of the timestamps.

# %%
tac_time = tac_readings[pids[0]]['timestamp']
tac_time = tac_time - tac_time.min()
tac_time.head(10)
# Out:
# 0       0
# 1    1983
# 2    2313
# 3    2643
# 4    2972
# 5    3302
# 6    3631
# 7    3960
# 8    4289
# 9    6118
# Name: timestamp, dtype: int64

# %% [markdown]
# TAC has been measured in g/dl where 0.08 is the legal limit for intoxication while driving. If the TAC reading is less than 0.02, the participant is considered to be not drunk. If the TAC reading is greater than 0.02 and less than 0.08, the participant is considered to be sober. If it is greater than 0.08, the participant is considered to be intoxicated.

# %%
lengths = [(df['timestamp'].max() - df['timestamp'].min()) / (60 * 60) for df in tac_readings.values()]
plt.figure(figsize=(20, 10))
plt.bar(pids, lengths)
plt.grid()
plt.xlabel('Participant ID')
plt.ylabel('Length of data stream (hours)')
plt.title('Length of data stream for each participant')
# Out:
# Text(0.5, 1.0, 'Length of data stream for each participant')

# %% [markdown]
# Extracting the groundtruth labels (sober - 1, not sober - 0) from the cleaned TAC data.

# %%
for pid in pids:
    accelerometer_data[pid]['ground_truth'] = [0] * accelerometer_data[pid].shape[0]
    for i, reading in tqdm(tac_readings[pid].iterrows(), desc=f"Processing {pid}'s TAC readings", total=len(tac_readings[pid])):
        if i != 0:
            t1, t2 = prev_reading['timestamp'], reading['timestamp']
            data = accelerometer_data[pid][(accelerometer_data[pid]['timestamp'] / 1000 >= t1) & (accelerometer_data[pid]['timestamp'] / 1000 < t2)]
            if not data.empty:
                if reading['TAC_Reading'] >= 0.02: accelerometer_data[pid].loc[data.index, 'ground_truth'] = 1
        prev_reading = reading
# Out:
# Processing BK7610's TAC readings: 100%|██████████| 57/57 [00:00<00:00, 71.83it/s]
# Processing BU4707's TAC readings: 100%|██████████| 57/57 [00:00<00:00, 260.21it/s]
# Processing CC6740's TAC readings: 100%|██████████| 56/56 [00:01<00:00, 41.63it/s]
# Processing DC6359's TAC readings: 100%|██████████| 55/55 [00:00<00:00, 182.38it/s]
# Processing DK3500's TAC readings: 100%|██████████| 51/51 [00:00<00:00, 68.18it/s]
# Processing HV0618's TAC readings: 100%|██████████| 54/54 [00:00<00:00, 54.59it/s]
# Processing JB3156's TAC readings: 100%|██████████| 55/55 [00:00<00:00, 73.32it/s]
# Processing JR8022's TAC readings: 100%|██████████| 47/47 [00:00<00:00, 345.49it/s]
# Processing MC7070's TAC readings: 100%|██████████| 56/56 [00:00<00:00, 336.98it/s]
# Processing MJ8002's TAC readings: 100%|██████████| 59/59 [00:00<00:00, 142.91it/s]
# Processing PC6771's TAC readings: 100%|██████████| 56/56 [00:02<00:00, 27.77it/s]
# Processing SA0297's TAC readings: 100%|██████████| 58/58 [00:00<00:00, 99.54it/s]
# Processing SF3079's TAC readings: 100%|██████████| 54/54 [00:00<00:00, 182.20it/s]

# %% [markdown]
# Writing the accelerometer data with groundtruth labels of each participant to csv files.

# %%
if not os.path.exists(f'{DATASET_PATH}/participant_data'):
    os.mkdir(f'{DATASET_PATH}/participant_data')
for pid in tqdm(pids, desc='Writing data'):
    accelerometer_data[pid].to_csv(f'{DATASET_PATH}/participant_data/{pid}_accelerometer_data.csv', index=False)
# Out:
# Writing data: 100%|██████████| 13/13 [01:15<00:00,  5.81s/it]

# %% [markdown]
# # Data Cleaning

# %%
if not os.path.exists(f'{DATASET_PATH}/clean_participant_data'):
    os.makedirs(f'{DATASET_PATH}/clean_participant_data')
else:
    for file in os.listdir(f'{DATASET_PATH}/clean_participant_data'):
        os.remove(f'{DATASET_PATH}/clean_participant_data/{file}')

for acc_data in tqdm(os.listdir(f'{DATASET_PATH}/participant_data'), desc='Cleaning accelerometer data'):
    pid = acc_data.split('_')[0]
    data = pd.read_csv(f'{DATASET_PATH}/participant_data/{acc_data}')
    sos = signal.cheby2(15, 40, 3, 'low', fs=40, output='sos')
    # Apply chebyshev type II filters of 15th order with 3Hz stopband to three axes
    data['x'] = signal.sosfilt(sos, data['x'])
    data['y'] = signal.sosfilt(sos, data['y'])
    data['z'] = signal.sosfilt(sos, data['z'])
    data.to_csv(f'{DATASET_PATH}/clean_participant_data/{acc_data}')
# Out:
# Cleaning accelerometer data: 100%|██████████| 13/13 [02:17<00:00, 10.60s/it]

# %% [markdown]
# # Data Segmentation
# Extract participant-wise accelerometer data + groundtruth labels.

# %%
accelerometer_data = {}

for acc_data in os.listdir(f'{DATASET_PATH}/clean_participant_data'):
    accelerometer_data[acc_data.split('_')[0]] = pd.read_csv(f'{DATASET_PATH}/clean_participant_data/{acc_data}', index_col=[0])

# %%
# acc_data1 = accelerometer_data['CC6740'] 
# type(acc_data1)
# acc_data1['timestamp']

# %%
if not os.path.exists(f'{DATASET_PATH}/segmented_participant_data'):
    os.makedirs(f'{DATASET_PATH}/segmented_participant_data')
else:
    for file in os.listdir(f'{DATASET_PATH}/segmented_participant_data'):
        os.remove(f'{DATASET_PATH}/segmented_participant_data/{file}')

for pid, data in accelerometer_data.items():
    # A long segment is of 10 seconds and a short segment is of 1 second
    # Short segments are sub-segments of the long segments in order to calculate features from a two-tiered approach
    long_seg_id, short_seg_id = 0, 0
    data['long_seg'] = 0
    data['short_seg'] = 0
    # strptime -> parse formatted string to datetime object
    # strftime -> format datetime object to string
    start_time = datetime.strptime(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(data['timestamp'][0] / 1000)), '%Y-%m-%d %H:%M:%S')
    short_seg_start, long_seg_start = start_time, start_time
    short_delta, long_delta = timedelta(seconds=1), timedelta(seconds=10)
    for i, row in tqdm(data.iterrows(), desc=f'Segmenting {pid}', total=len(data)):
        # Current timestamp
        timestamp = datetime.strptime(time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(row['timestamp'] / 1000)), '%Y-%m-%d %H:%M:%S')
        # When the current timestamp is greater or equal to the start of the current 10 second window + 10 seconds, we start a new 10 second window
        if timestamp >= long_seg_start + long_delta:
            if short_seg_id < 9:
                start_id = data.index[data['timestamp'] // 1000 == int(time.mktime(long_seg_start.timetuple()))][0]
                end_id = i
                data.loc[data.index[start_id:end_id], 'long_seg'] = -1
                long_seg_id -= 1
            # Start of a new long segment
            long_seg_id += 1
            short_seg_id = 0
            long_seg_start = timestamp
            short_seg_start = long_seg_start
        # When the current timestamp is greater or equal to the start of the current 1 second window + 1 second, we start a new 1 second window
        if timestamp >= short_seg_start + short_delta:
            short_seg_id += 1
            short_seg_start = timestamp
        # Update the current long segment
        data.at[i, 'long_seg'] = long_seg_id
        # Update the current short segment
        data.at[i, 'short_seg'] = short_seg_id
    if short_seg_id < 9:
        start_id = data.index[data['timestamp'] // 1000 == int(time.mktime(long_seg_start.timetuple()))][0]
        end_id = len(data)
        data.loc[data.index[start_id:end_id], 'long_seg'] = -1

    data.to_csv(f'{DATASET_PATH}/segmented_participant_data/{pid}_segmented.csv', index=False)
    print(f'{long_seg_id + 1} windows extracted for {pid}')
# Out:
# Segmenting BK7610: 100%|██████████| 1225727/1225727 [02:57<00:00, 6908.46it/s]
# 3068 windows extracted for BK7610
# Segmenting BU4707: 100%|██████████| 447423/447423 [00:46<00:00, 9543.68it/s]
# 1119 windows extracted for BU4707
# Segmenting CC6740: 100%|██████████| 2374694/2374694 [05:46<00:00, 6848.81it/s]
# 5527 windows extracted for CC6740
# Segmenting DC6359: 100%|██████████| 591358/591358 [01:02<00:00, 9502.15it/s]
# 1546 windows extracted for DC6359
# Segmenting DK3500: 100%|██████████| 1339622/1339622 [03:10<00:00, 7036.89it/s]
# 3364 windows extracted for DK3500
# Segmenting HV0618: 100%|██████████| 1876013/1876013 [04:28<00:00, 6984.00it/s]
# 4702 windows extracted for HV0618
# Segmenting JB3156: 100%|██████████| 1177748/1177748 [02:48<00:00, 6969.19it/s]
# 2042 windows extracted for JB3156
# Segmenting JR8022: 100%|██████████| 307526/307526 [00:33<00:00, 9206.32it/s]
# 767 windows extracted for JR8022
# Segmenting MC7070: 100%|██████████| 318600/318600 [00:32<00:00, 9762.51it/s]
# 796 windows extracted for MC7070
# Segmenting MJ8002: 100%|██████████| 631303/631303 [01:06<00:00, 9548.30it/s]
# 1578 windows extracted for MJ8002
# Segmenting PC6771: 100%|██████████| 2141701/2141701 [05:03<00:00, 7055.36it/s]
# 5357 windows extracted for PC6771
# Segmenting SA0297: 100%|██████████| 962901/962901 [01:40<00:00, 9569.45it/s]
# 4361 windows extracted for SA0297
# Segmenting SF3079: 100%|██████████| 662949/662949 [01:08<00:00, 9614.46it/s]
# 1660 windows extracted for SF3079

# %% [markdown]
# # Feature Extraction
#
# For each axis, we will use a set of statistical metrics as well as some spectral features per window of 10 seconds in length. The window size is chosen arbitrarily and has to be tuned for the optimal value. The idea is to subdivide a window further into smaller windows of 1 second each and compute the metrics for each short-term window (this is also known as the two-tiered window approach) to characterize the data as it changes with time. Then, we'll compute the mean, variance, min and max along with the mean of the lower third and upper third of sorted values, creating a total of 6 summary statistics per metric per 10 second window per axis that results in 18 features per metric in total. We'll also calculate the difference between the previous window and the current window for each feature which will double the number of features per window per metric (36).
#
# The feature extraction is done per participant data with the intention of splitting the data into training and test sets by participant. To keep the most relevant features, we will calculate the feature importance of each feature by converting the feature selection problem into a supervised learning problem. The traditional way of doing feature selection is computing the correlation between the features and removing one of highly correlated pairs of features and keeping the other. However, when there're many features, this approach is not feasible. Hence, we will use a Random Forest regressor to compute the feature importance. To select features automatically, we will use Recursive Feature Elimination (RFE) that'll use the random forest regressor as the predictive model to weight features and prune those with the smallest weights.

# %%
def zero_crossing_rate(data):
    return np.sum(np.abs(np.diff(np.sign(data)))) / (2 * (len(data) - 1))

def spectral_entropy(signal, n_short_blocks=10, eps=1e-9):
    """Computes the spectral entropy"""
    # number of frame samples
    num_frames = len(signal)
    # total spectral energy
    total_energy = np.sum(signal ** 2)
    # length of sub-frame
    sub_win_len = int(np.floor(num_frames / n_short_blocks))
    if num_frames != sub_win_len * n_short_blocks:
        signal = signal[0:sub_win_len * n_short_blocks]
    # define sub-frames (using matrix reshape)
    sub_wins = signal.reshape(sub_win_len, n_short_blocks, order='F').copy()
    # compute spectral sub-energies
    s = np.sum(sub_wins ** 2, axis=0) / (total_energy + eps)
    # compute spectral entropy
    entropy = -np.sum(s * np.log2(s + eps))
    return entropy

def spectral_centroid(fft_magnitude, sampling_rate=40, eps=1e-9):
    ind = (np.arange(1, len(fft_magnitude) + 1)) * (sampling_rate / (2.0 * len(fft_magnitude)))
    Xt = fft_magnitude.copy()
    Xt = Xt / Xt.max()
    NUM = np.sum(ind * Xt)
    DEN = np.sum(Xt) + eps
    # Centroid:
    centroid = (NUM / DEN)
    # Normalize:
    centroid = centroid / (sampling_rate / 2.0)
    return centroid

def spectral_spread(fft_magnitude, sampling_rate=40, eps=1e-9):
    ind = (np.arange(1, len(fft_magnitude) + 1)) * (sampling_rate / (2.0 * len(fft_magnitude)))
    Xt = fft_magnitude.copy()
    Xt = Xt / Xt.max()
    NUM = np.sum(ind * Xt)
    DEN = np.sum(Xt) + eps
    # Spread:
    spread = np.sqrt(np.sum(((ind - (NUM / DEN)) ** 2) * Xt) / DEN)
    # Normalize:
    spread = spread / (sampling_rate / 2.0)
    return spread

def spectral_flux(fft_magnitude, previous_fft_magnitude, eps=1e-9):
    # compute the spectral flux as the sum of square distances:
    fft_sum = np.sum(fft_magnitude + eps)
    previous_fft_sum = np.sum(previous_fft_magnitude + eps)
    sp_flux = np.sum((fft_magnitude / fft_sum - previous_fft_magnitude / previous_fft_sum) ** 2)
    return sp_flux

def spectral_rolloff(signal, c=0.90, eps=1e-9):
    energy = np.sum(signal ** 2)
    fft_length = len(signal)
    threshold = c * energy
    # Find the spectral rolloff as the frequency position where the respective spectral energy is equal to c*totalEnergy
    cumulative_sum = np.cumsum(signal ** 2) + eps
    a = np.nonzero(cumulative_sum > threshold)[0]
    sp_rolloff = 0.0
    if len(a) > 0: sp_rolloff = np.float64(a[0]) / (float(fft_length))
    return sp_rolloff

def spectral_peak_ratio(fft_magnitude, eps=1e-9):
    # Ratio of largest peak to second largest peak
    peaks = sorted(fft_magnitude, reverse=True)
    if len(peaks) < 2: return 0.0
    return peaks[0] / (peaks[1] + eps)

def max_frequency(fft_magnitude, sampling_rate=40):
    max_freq = np.argmax(fft_magnitude)
    max_freq *= (sampling_rate / (2.0 * len(fft_magnitude)))
    return max_freq

def mfcc_filter_banks(sampling_rate, num_fft, lowfreq=133.33, linc=200 / 3,
                      logsc=1.0711703, num_lin_filt=13, num_log_filt=27):
    """
    Computes the triangular filterbank for MFCC computation 
    (used in the stFeatureExtraction function before the stMFCC function call)
    This function is taken from the scikits.talkbox library (MIT Licence):
    https://pypi.python.org/pypi/scikits.talkbox
    """

    if sampling_rate < 8000:
        nlogfil = 5

    # Total number of filters
    num_filt_total = num_lin_filt + num_log_filt

    # Compute frequency points of the triangle:
    frequencies = np.zeros(num_filt_total + 2)
    frequencies[:num_lin_filt] = lowfreq + np.arange(num_lin_filt) * linc
    frequencies[num_lin_filt:] = frequencies[num_lin_filt - 1] * logsc ** \
                                 np.arange(1, num_log_filt + 3)
    heights = 2. / (frequencies[2:] - frequencies[0:-2])

    # Compute filterbank coeff (in fft domain, in bins)
    fbank = np.zeros((num_filt_total, num_fft))
    nfreqs = np.arange(num_fft) / (1. * num_fft) * sampling_rate

    for i in range(num_filt_total):
        low_freqs = frequencies[i]
        cent_freqs = frequencies[i + 1]
        high_freqs = frequencies[i + 2]

        lid = np.arange(np.floor(low_freqs * num_fft / sampling_rate) + 1,
                        np.floor(cent_freqs * num_fft / sampling_rate) + 1,
                        dtype=np.int)
        lslope = heights[i] / (cent_freqs - low_freqs)
        rid = np.arange(np.floor(cent_freqs * num_fft / sampling_rate) + 1,
                        np.floor(high_freqs * num_fft / sampling_rate) + 1,
                        dtype=np.int)
        rslope = heights[i] / (high_freqs - cent_freqs)
        fbank[i][lid] = lslope * (nfreqs[lid] - low_freqs)
        fbank[i][rid] = rslope * (high_freqs - nfreqs[rid])

    return fbank, frequencies

def mfcc(fft_magnitude, fbank, num_mfcc_feats, eps=1e-9):
    """
    Computes the MFCCs of a frame, given the fft mag
    ARGUMENTS:
        fft_magnitude:  fft magnitude abs(FFT)
        fbank:          filter bank (see mfccInitFilterBanks)
    RETURN
        ceps:           MFCCs (13 element vector)
    Note:    MFCC calculation is, in general, taken from the 
             scikits.talkbox library (MIT Licence),
    #    with a small number of modifications to make it more 
         compact and suitable for the pyAudioAnalysis Lib
    """

    mspec = np.log10(np.dot(fft_magnitude, fbank.T) + eps)
    ceps = dct(mspec, type=2, norm='ortho', axis=-1)[:num_mfcc_feats]
    return ceps

def avg_power(sig):
    _, power = signal.welch(sig, 40, nperseg=len(sig))
    return np.mean(power)

def rms(signal):
    return np.sqrt(np.mean(signal ** 2))

# %%
if not os.path.exists(f'{DATASET_PATH}/feature_data'):
    os.makedirs(f'{DATASET_PATH}/feature_data')
else:
    for file in os.listdir(f'{DATASET_PATH}/feature_data'):
        os.remove(f'{DATASET_PATH}/feature_data/{file}')

# %%
metrics = {
    'mean': np.mean, 
    'std': np.std,
    'avg_abs_dev': lambda x: np.mean(np.abs(x - np.mean(x))),
    'min_raw': np.min,
    'max_raw': np.max,
    'min_abs': lambda x: np.min(np.abs(x)),
    'max_abs': lambda x: np.max(np.abs(x)), 
    'median': np.median, 
    'inter_quartile_range': lambda x: np.percentile(x, 75) - np.percentile(x, 25),
    'zero_crossing_rate': zero_crossing_rate, 
    'skewness': skew, 
    'kurtosis': kurtosis, 
    'spectral_entropy': spectral_entropy, 
    'fft_spectral_entropy': spectral_entropy,
    'fft_spectral_centroid': spectral_centroid, 
    'fft_spectral_spread': spectral_spread,
    'fft_spectral_rolloff': spectral_rolloff,
    'fft_spectral_peak_ratio': spectral_peak_ratio,
    'avg_power': avg_power,
    'rms': rms,
    'max_freq': max_frequency
    # TODO: #6 The metrics "spectral_flux" and "mfcc" require the window sizes to be equal
    # 'fft_spectral_flux': spectral_flux,
    # 'fft_mfcc', 
}

n_mfcc_features = 13

summary_stats = {
    'mean': np.mean,
    'variance': np.var,
    'min': np.min,
    'max': np.max,
    'lower_third_mean': lambda x: np.mean(sorted(x)[:len(x) // 3]),
    'upper_third_mean': lambda x: np.mean(sorted(x)[len(x) // 3:])
}

# %%
data = pd.read_csv(f'{DATASET_PATH}/segmented_participant_data/JB3156_segmented.csv')
long_seg = data.groupby(['long_seg'])

# %%
for acc_data in os.listdir(f'{DATASET_PATH}/segmented_participant_data'):
    pid = acc_data.split('_')[0]
    data = pd.read_csv(f'{DATASET_PATH}/segmented_participant_data/{acc_data}')
    feature_df = pd.DataFrame()
    columns = []
    ground_truth = []
    for long_seg_id, long_seg in tqdm(data.groupby(['long_seg']), desc=f'Extracting features for {pid}', total=len(data['long_seg'].unique())):
        if long_seg['long_seg'].unique()[0] == -1: continue
        short_segs = [short_seg for _, short_seg in long_seg.groupby(['short_seg'])]
        short_seg_fft_mag = [{axis: np.abs(fftpack.fft(seg[axis].to_numpy())) for axis in ['x', 'y', 'z']} for seg in short_segs]
        row = []
        bad_seg = False
        for metric_name, metric in metrics.items():
            # Compute the metric for each short segment
            short_term_features = {'x': [], 'y': [], 'z': []}

            def apply_metric(seg_id, axis):
                if metric_name.split('_')[0] != 'fft':
                    return metric(short_segs[seg_id][axis].to_numpy())
                if metric_name == 'fft_spectral_flux':
                    fft_mag_prev = short_seg_fft_mag[seg_id - 1][axis] if seg_id > 0 else short_seg_fft_mag[seg_id][axis]
                    return metric(short_seg_fft_mag[seg_id][axis], fft_mag_prev)
                return metric(short_seg_fft_mag[seg_id][axis])
            
            for short_seg_id in range(10):
                if len(short_segs[short_seg_id]) <= 1:
                    bad_seg = True
                    break
                short_term_features['x'].append(apply_metric(short_seg_id, 'x'))
                short_term_features['y'].append(apply_metric(short_seg_id, 'y'))
                short_term_features['z'].append(apply_metric(short_seg_id, 'z'))

            if bad_seg: break
            
            # Now compute the summary statistics for the metric for the current long segment
            for axis, axis_data in short_term_features.items():
                for summary_stat_name, summary_stat in summary_stats.items():
                    row.append(summary_stat(axis_data))
                    if long_seg_id == 0:
                        columns.append(f'{axis}_{metric_name}_{summary_stat_name}')

        if bad_seg: continue
        # print(long_seg_id)
        ground_truth.append(long_seg['ground_truth'].value_counts().idxmax())

        temp = row
        if long_seg_id == 0:
            columns.extend([f'{feature_name}_diff' for feature_name in columns])
            feature_df = pd.DataFrame(columns=columns)
            row *= 2
        else:
            row.extend([row[i] - prev_row[i] for i in range(len(row))])
        feature_df.loc[long_seg_id] = row
        prev_row = temp
    feature_df['ground_truth'] = ground_truth
    feature_df.to_csv(f'{DATASET_PATH}/feature_data/{pid}.csv', index=False)
# Out:
# Extracting features for BK7610: 100%|██████████| 3068/3068 [04:13<00:00, 12.08it/s]
# Extracting features for BU4707: 100%|██████████| 1119/1119 [01:26<00:00, 12.88it/s]
# Extracting features for CC6740: 100%|██████████| 5527/5527 [07:34<00:00, 12.17it/s]
# Extracting features for DC6359: 100%|██████████| 1546/1546 [02:03<00:00, 12.50it/s]
# Extracting features for DK3500: 100%|██████████| 3364/3364 [04:38<00:00, 12.10it/s]
# Extracting features for HV0618: 100%|██████████| 4702/4702 [06:30<00:00, 12.04it/s]
# Extracting features for JB3156:  15%|█▌        | 310/2042 [00:25<02:03, 13.97it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  15%|█▌        | 312/2042 [00:25<02:05, 13.76it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  15%|█▌        | 316/2042 [00:25<02:06, 13.65it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  16%|█▌        | 320/2042 [00:25<02:07, 13.53it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  16%|█▌        | 322/2042 [00:26<02:07, 13.50it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  16%|█▌        | 324/2042 [00:26<02:08, 13.37it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  16%|█▌        | 328/2042 [00:26<02:11, 13.06it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  16%|█▋        | 334/2042 [00:27<02:06, 13.53it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  16%|█▋        | 336/2042 [00:27<02:06, 13.45it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  17%|█▋        | 338/2042 [00:27<02:06, 13.47it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  17%|█▋        | 340/2042 [00:27<02:08, 13.22it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  17%|█▋        | 342/2042 [00:27<02:09, 13.16it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  17%|█▋        | 344/2042 [00:27<02:16, 12.45it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  17%|█▋        | 346/2042 [00:27<02:14, 12.59it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  17%|█▋        | 348/2042 [00:28<02:14, 12.56it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  17%|█▋        | 350/2042 [00:28<02:12, 12.73it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  17%|█▋        | 352/2042 [00:28<02:16, 12.34it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  17%|█▋        | 354/2042 [00:28<02:13, 12.68it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  17%|█▋        | 356/2042 [00:28<02:13, 12.66it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  18%|█▊        | 358/2042 [00:28<02:15, 12.46it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  18%|█▊        | 360/2042 [00:29<02:15, 12.43it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  18%|█▊        | 364/2042 [00:29<02:10, 12.90it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  18%|█▊        | 366/2042 [00:29<02:11, 12.74it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  18%|█▊        | 368/2042 [00:29<02:09, 12.90it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  18%|█▊        | 370/2042 [00:29<02:09, 12.90it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  18%|█▊        | 372/2042 [00:30<02:11, 12.73it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  19%|█▊        | 382/2042 [00:30<02:01, 13.67it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  19%|█▉        | 384/2042 [00:30<02:00, 13.81it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  19%|█▉        | 386/2042 [00:31<02:00, 13.79it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  19%|█▉        | 388/2042 [00:31<02:21, 11.70it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  19%|█▉        | 390/2042 [00:31<02:36, 10.57it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  19%|█▉        | 392/2042 [00:31<02:46,  9.91it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  19%|█▉        | 394/2042 [00:31<02:51,  9.61it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  19%|█▉        | 395/2042 [00:32<02:52,  9.53it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  19%|█▉        | 396/2042 [00:32<02:55,  9.36it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  20%|█▉        | 400/2042 [00:32<03:08,  8.71it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  20%|█▉        | 401/2042 [00:32<03:09,  8.68it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  20%|█▉        | 402/2042 [00:32<03:05,  8.82it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  20%|█▉        | 403/2042 [00:32<03:06,  8.79it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  20%|█▉        | 404/2042 [00:33<03:07,  8.71it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  20%|█▉        | 405/2042 [00:33<03:08,  8.68it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  20%|█▉        | 406/2042 [00:33<03:06,  8.78it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  20%|██        | 415/2042 [00:34<03:01,  8.95it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  21%|██        | 424/2042 [00:35<02:13, 12.16it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  21%|██        | 426/2042 [00:35<02:07, 12.65it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  21%|██        | 428/2042 [00:35<02:07, 12.69it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  21%|██        | 430/2042 [00:35<02:07, 12.61it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  21%|██        | 432/2042 [00:35<02:08, 12.50it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  21%|██▏       | 434/2042 [00:35<02:07, 12.66it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  21%|██▏       | 436/2042 [00:36<02:06, 12.73it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  21%|██▏       | 438/2042 [00:36<02:05, 12.80it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  22%|██▏       | 440/2042 [00:36<02:05, 12.75it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  22%|██▏       | 442/2042 [00:36<02:04, 12.89it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  22%|██▏       | 444/2042 [00:36<02:04, 12.87it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  22%|██▏       | 446/2042 [00:36<02:08, 12.44it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  22%|██▏       | 448/2042 [00:36<02:05, 12.67it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  22%|██▏       | 456/2042 [00:37<01:58, 13.43it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  22%|██▏       | 458/2042 [00:37<02:00, 13.15it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  23%|██▎       | 460/2042 [00:37<02:02, 12.89it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  23%|██▎       | 462/2042 [00:38<02:03, 12.74it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  23%|██▎       | 464/2042 [00:38<02:03, 12.75it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  23%|██▎       | 466/2042 [00:38<02:02, 12.88it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  23%|██▎       | 468/2042 [00:38<02:02, 12.81it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  23%|██▎       | 470/2042 [00:38<02:01, 12.97it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  23%|██▎       | 474/2042 [00:38<02:00, 12.99it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  23%|██▎       | 476/2042 [00:39<01:59, 13.06it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  24%|██▍       | 488/2042 [00:40<01:57, 13.23it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  24%|██▍       | 500/2042 [00:40<01:54, 13.42it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  25%|██▍       | 502/2042 [00:41<01:55, 13.28it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  25%|██▍       | 504/2042 [00:41<01:56, 13.23it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  25%|██▍       | 506/2042 [00:41<01:55, 13.29it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  25%|██▍       | 508/2042 [00:41<01:56, 13.17it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  25%|██▍       | 510/2042 [00:41<01:54, 13.37it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  25%|██▌       | 512/2042 [00:41<01:56, 13.11it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  25%|██▌       | 514/2042 [00:41<01:57, 12.97it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  25%|██▌       | 516/2042 [00:42<01:56, 13.09it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  26%|██▌       | 526/2042 [00:42<01:56, 13.03it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  26%|██▌       | 528/2042 [00:43<01:56, 12.97it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  26%|██▌       | 530/2042 [00:43<01:57, 12.89it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  26%|██▌       | 532/2042 [00:43<01:56, 12.93it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  26%|██▋       | 538/2042 [00:43<01:53, 13.28it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  26%|██▋       | 540/2042 [00:43<01:56, 12.92it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  27%|██▋       | 542/2042 [00:44<01:55, 13.03it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  27%|██▋       | 544/2042 [00:44<01:54, 13.05it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  27%|██▋       | 546/2042 [00:44<01:55, 12.99it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  27%|██▋       | 550/2042 [00:44<02:05, 11.93it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  27%|██▋       | 552/2042 [00:45<02:20, 10.64it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  27%|██▋       | 554/2042 [00:45<02:29,  9.98it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  27%|██▋       | 556/2042 [00:45<02:35,  9.57it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  27%|██▋       | 557/2042 [00:45<02:36,  9.47it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  27%|██▋       | 561/2042 [00:46<02:44,  8.99it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  28%|██▊       | 562/2042 [00:46<02:44,  9.00it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  28%|██▊       | 563/2042 [00:46<02:46,  8.88it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  28%|██▊       | 568/2042 [00:46<02:47,  8.78it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  28%|██▊       | 569/2042 [00:46<02:48,  8.76it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  28%|██▊       | 570/2042 [00:47<02:51,  8.60it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  28%|██▊       | 575/2042 [00:47<02:43,  8.99it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  28%|██▊       | 576/2042 [00:47<02:45,  8.86it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  28%|██▊       | 577/2042 [00:47<02:48,  8.67it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  28%|██▊       | 578/2042 [00:47<02:47,  8.77it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  30%|██▉       | 609/2042 [00:50<01:46, 13.42it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  30%|██▉       | 611/2042 [00:50<01:46, 13.47it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# ...
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  90%|████████▉ | 1833/2042 [02:35<00:17, 11.82it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  90%|████████▉ | 1835/2042 [02:35<00:18, 11.07it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  90%|████████▉ | 1837/2042 [02:35<00:20,  9.92it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  90%|█████████ | 1839/2042 [02:36<00:22,  8.84it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  90%|█████████ | 1840/2042 [02:36<00:22,  8.87it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  90%|█████████ | 1841/2042 [02:36<00:22,  8.89it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  90%|█████████ | 1842/2042 [02:36<00:22,  8.94it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  90%|█████████ | 1843/2042 [02:36<00:22,  8.77it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  90%|█████████ | 1844/2042 [02:36<00:22,  8.85it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  90%|█████████ | 1845/2042 [02:36<00:22,  8.59it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  90%|█████████ | 1846/2042 [02:36<00:22,  8.53it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  90%|█████████ | 1847/2042 [02:36<00:22,  8.66it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  91%|█████████ | 1853/2042 [02:37<00:21,  8.84it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  91%|█████████ | 1854/2042 [02:37<00:23,  8.00it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  91%|█████████ | 1856/2042 [02:38<00:22,  8.23it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  91%|█████████ | 1858/2042 [02:38<00:22,  8.09it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  91%|█████████ | 1859/2042 [02:38<00:22,  8.25it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  91%|█████████ | 1862/2042 [02:38<00:21,  8.36it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  91%|█████████ | 1863/2042 [02:38<00:22,  8.12it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  92%|█████████▏| 1869/2042 [02:39<00:21,  7.92it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  92%|█████████▏| 1870/2042 [02:39<00:21,  7.95it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  92%|█████████▏| 1871/2042 [02:39<00:21,  7.81it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  92%|█████████▏| 1872/2042 [02:39<00:21,  8.08it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  92%|█████████▏| 1874/2042 [02:40<00:17,  9.41it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  92%|█████████▏| 1876/2042 [02:40<00:16, 10.30it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  92%|█████████▏| 1878/2042 [02:40<00:15, 10.71it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  92%|█████████▏| 1880/2042 [02:40<00:14, 11.04it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  92%|█████████▏| 1882/2042 [02:40<00:14, 11.28it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  92%|█████████▏| 1884/2042 [02:41<00:14, 11.07it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  92%|█████████▏| 1886/2042 [02:41<00:14, 10.86it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  92%|█████████▏| 1888/2042 [02:41<00:13, 11.13it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  93%|█████████▎| 1896/2042 [02:42<00:12, 11.76it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  93%|█████████▎| 1904/2042 [02:42<00:11, 12.23it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# <ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  93%|█████████▎| 1906/2042 [02:42<00:11, 12.26it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  93%|█████████▎| 1908/2042 [02:43<00:11, 11.94it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156:  94%|█████████▍| 1920/2042 [02:44<00:09, 12.26it/s]<ipython-input-25-b4162e476692>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   return metric(short_segs[seg_id][axis].to_numpy())
# Extracting features for JB3156: 100%|██████████| 2042/2042 [02:55<00:00, 11.65it/s]
# Extracting features for JR8022: 100%|██████████| 767/767 [01:06<00:00, 11.58it/s]
# Extracting features for MC7070: 100%|██████████| 796/796 [01:08<00:00, 11.67it/s]
# Extracting features for MJ8002: 100%|██████████| 1578/1578 [02:16<00:00, 11.56it/s]
# Extracting features for PC6771: 100%|██████████| 5357/5357 [07:59<00:00, 11.17it/s]
# Extracting features for SA0297: 100%|██████████| 4361/4361 [06:31<00:00, 11.14it/s]
# Extracting features for SF3079: 100%|██████████| 1660/1660 [02:24<00:00, 11.46it/s]
